# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
U0 = 1000
N = 1000
dx = 0.005

def potential(x):
    U = np.zeros_like(x)
    pos = np.where(x > 1)
    U[pos] = U0
    return U

def equation(U, psi):
    return (U - E)*psi

x = np.linspace(0, (N-1)*dx, N)
U = potential(x)
E = 1

def solver(E):
    for i in range(1,N):
        psi_prime[i] = psi_prime[i-1] + equation(U[i-1], psi[i-1])*dx
        psi[i] = psi[i-1] + psi_prime[i]*dx
    return psi

# %%
E = 0
psi = np.ones(N); psi_prime = np.ones(N)
for i in range(9):
    E = i**2*np.pi**2
    psi[0] = 0
    psi_prime[0] = 1
    psi[-1] = 100
    psi = solver(E)
#    while abs(psi[-1]) > 10 and E < U0:
#        E += 0.01
#        psi = solver(E)
#    print(E)
    plt.plot(x, psi)
    plt.xlim(-1, 2)
    plt.ylim(-0.5, 0.5)
